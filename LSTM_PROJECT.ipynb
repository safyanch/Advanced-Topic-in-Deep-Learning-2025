# %%
faqs = """About the Program

What is the course fee for the Data Science & AI Mentorship Program (DSAIM 2025)?
The program follows a monthly subscription model where learners pay Rs 850 per month. This allows students from all over Pakistan to join at an affordable cost without large upfront payments.

What is the total duration of the course?
The total duration is 7 months, with a complete learning roadmap covering Python, Machine Learning, and real-world case studies. Hence, the total course fee is around Rs 5950 for the entire program.

What is included in the mentorship program?
We cover both theoretical and practical modules to ensure industry readiness:

Python Fundamentals

Data Science Libraries (NumPy, Pandas, Matplotlib, Seaborn)

Data Cleaning and Analysis

SQL for Data Science

Statistics & Mathematics for ML

Machine Learning Algorithms

MLOps and Deployment

Portfolio & Case Studies

You can check the detailed outline on our website: https://datasciencepakistan.org/programs

Will Deep Learning and NLP be covered?
Yes, in the Advanced Module (optional), Deep Learning and Natural Language Processing will be introduced with TensorFlow and Hugging Face.

What if I miss a live session? Will I get recordings?
Yes, all live sessions are recorded and uploaded to the Learning Management System (LMS). You can access them anytime within your active subscription.

Where can I find the class schedule?
You can view the monthly schedule in the shared Google Sheet here:
https://docs.google.com/spreadsheets/d/PKDSAIM2025

What is the average time duration of each live class?
Each live class runs for 2 hours, including Q&A and hands-on practice sessions.

Which language will be used during sessions?
The sessions will be conducted in Urdu and English (mixed), making them easy to follow for all learners.

How will students be informed about upcoming sessions?
Registered learners receive an email and WhatsApp message before every session with the joining link and resources.

Can students from non-technical backgrounds join?
Absolutely. The program starts from scratch and assumes no prior programming background.

Can I join the program in the middle?
Yes, students can join anytime. The LMS access gives you recordings of all previous sessions instantly after payment.

Will I get access to old content if I join late?
Yes, you will get full access to all previously recorded modules and assignments once you activate your subscription.

Do we have to submit tasks and projects?
Yes. Weekly assignments and a final capstone project are part of the evaluation process. Submissions are done through the LMS dashboard.

Will we work on real case studies?
Yes, every module includes a case study — such as analyzing Pakistan Stock Exchange data, weather data, or COVID-19 trends in Pakistan.

Where can we reach for technical or course-related support?
You can contact us at support@datasciencepakistan.org
 or through the “Help” section on your LMS dashboard.

Payment & Registration

Where do we make payments?
Payments can be made through our official website:
https://datasciencepakistan.org

We accept JazzCash, Easypaisa, and debit/credit card payments.

Can I pay the full amount at once?
Yes, you can choose to pay all seven months together to receive a 10% discount.

What is the monthly validity period?
Each subscription is valid for 30 days from the date of payment. If you join on 10th January, your next payment is due by 10th February.

What if I am not satisfied with the course after payment?
We offer a 7-day refund policy. You can email us within seven days of payment to request a refund, no questions asked.

I live outside Pakistan and cannot pay via local gateways. What should I do?
You can contact our team at support@datasciencepakistan.org
 to receive an international payment link via PayPal or Stripe.

Will I still get updates if I haven’t made the latest payment?
You’ll continue receiving newsletters, but your LMS access will be paused until the next payment is made.

After Registration

How long can I watch paid videos after purchase?
You can view all videos for the duration of your subscription period. Once the entire course fee is paid, you’ll retain access to the content until August 2026.

Why don’t you provide lifetime access?
We keep costs low and update our curriculum every year. Lifetime access is not feasible at this price.

How do I ask questions after the session?
A Google Form is available in your LMS dashboard for submitting doubts. Our mentors respond via one-on-one Zoom sessions every Friday.

If I join late, can I still ask previous session doubts?
Yes, just select the module and week number in the doubt form.

What if I lose access to the LMS?
You can recover your account anytime using your registered email. Technical support is available 24/7.

Certificate & Career Support

What is the certificate eligibility criteria?
There are two main requirements:

You must complete all 7 months of payment.

You must attempt and submit all course projects.

Can I pay for missed months later?
Yes. A special “Make-Up Fee” link will be available on your dashboard for pending months.

Do you provide placement assistance?
Yes, but placement assistance ≠ placement guarantee. We help you with:

Portfolio-building workshops

Resume & LinkedIn profile sessions

Mock interviews with industry mentors

Internship and freelancing guidance

Will I get guaranteed job placement?
No. The program provides skill-building and career support, not guaranteed jobs.

What type of projects are part of the portfolio?
Students complete 3 mini-projects and one capstone project, such as:

Predicting electricity demand in Pakistan

Analyzing PSL player statistics

Building a chatbot for customer queries

COVID-19 vaccination trend visualization

What is the format of the certificate?
Certificates are digital (PDF) and verifiable via QR code. A printed version can be mailed for Rs 400 extra.

Can I continue learning after completing the program?
Yes. You can join our Advanced AI Fellowship (AAF) for Deep Learning, NLP, and Computer Vision.

Contact & Communication

Where can I ask general questions?
You can email us at info@datasciencepakistan.org
 or join our official Telegram community for discussions.

Will I get mentorship support after course completion?
Yes, alumni receive access to monthly mentor meetups and career clinics for one year after graduation.

Do you organize hackathons or challenges?
Yes. We conduct bi-monthly hackathons with cash prizes and internship opportunities for top performers.

Where are the sessions conducted?
Sessions are hosted live on Zoom and managed through our LMS platform. On-site classes are available in Karachi, Lahore, and Islamabad.

In short:
The Data Science & AI Mentorship Program (Pakistan) is a 7-month guided journey blending affordability, mentorship, and project-based learning for aspiring data scientists. Whether you’re from a tech or non-tech background, this program is structured to make you industry-ready through live sessions, local datasets, and one-on-one mentorship.
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 458

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[100, 1],
#  [100, 1, 13],
#  [12, 7],
#  [12, 7, 1],
#  [12, 7, 1, 27],
#  [12, 7, 1, 27, 67],
#  [12, 7, 1, 27, 67, 6],
#  [12, 7, 1, 27, 67, 6, 1],
#  [12, 7, 1, 27, 67, 6, 1, 28],
#  [12, 7, 1, 27, 67, 6, 1, 28, 54],
#  [12, 7, 1, 27, 67, 6, 1, 28, 54, 68],
#  [12, 7, 1, 27, 67, 6, 1, 28, 54, 68, 37],
#  [12, 7, 1, 27, 67, 6, 1, 28, 54, 68, 37, 13],
#  [12, 7, 1, 27, 67, 6, 1, 28, 54, 68, 37, 13, 165],
#  [12, 7, 1, 27, 67, 6, 1, 28, 54, 68, 37, 13, 165, 166],
#  [1, 13],
#  [1, 13, 167],
#  [1, 13, 167, 8],
#  [1, 13, 167, 8, 44],
#  [1, 13, 167, 8, 44, 45],
#  [1, 13, 167, 8, 44, 45, 168],
#  [1, 13, 167, 8, 44, 45, 168, 38],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69, 46],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69, 46, 70],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69, 46, 70, 169],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69, 46, 70, 169, 170],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69, 46, 70, 169, 170, 101],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69, 46, 70, 169, 170, 101, 71],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69, 46, 70, 169, 170, 101, 71, 171],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69, 46, 70, 169, 170, 101, 71, 171, 47],
#  [1, 13, 167, 8, 44, 45, 168, 38, 69, 46, 70, 169, 170, 101, 71, 171, 47, 48],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9,
#   23],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9,
#   23,
#   40],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9,
#   23,
#   40,
#   72],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9,
#   23,
#   40,
#   72,
#   173],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9,
#   23,
#   40,
#   72,
#   173,
#   174],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9,
#   23,
#   40,
#   72,
#   173,
#   174,
#   175],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9,
#   23,
#   40,
#   72,
#   173,
#   174,
#   175,
#   176],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9,
#   23,
#   40,
#   72,
#   173,
#   174,
#   175,
#   176,
#   177],
#  [1,
#   13,
#   167,
#   8,
#   44,
#   45,
#   168,
#   38,
#   69,
#   46,
#   70,
#   169,
#   170,
#   101,
#   71,
#   171,
#   47,
#   48,
#   22,
#   172,
#   39,
#   9,
#   23,
#   40,
#   72,
#   173,
#   174,
#   175,
#   176,
#   177,
#   55],
#  [12, 7],
#  [12, 7, 1],
#  [12, 7, 1, 73],
#  [12, 7, 1, 73, 56],
#  [12, 7, 1, 73, 56, 14],
#  [12, 7, 1, 73, 56, 14, 1],
#  [12, 7, 1, 73, 56, 14, 1, 27],
#  [1, 73],
#  [1, 73, 56],
#  [1, 73, 56, 7],
#  [1, 73, 56, 7, 49],
#  [1, 73, 56, 7, 49, 50],
#  [1, 73, 56, 7, 49, 50, 32],
#  [1, 73, 56, 7, 49, 50, 32, 8],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74, 24],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74, 24, 178],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74, 24, 178, 179],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74, 24, 178, 179, 102],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74, 24, 178, 179, 102, 103],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74, 24, 178, 179, 102, 103, 24],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74, 24, 178, 179, 102, 103, 24, 2],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74, 24, 178, 179, 102, 103, 24, 2, 104],
#  [1, 73, 56, 7, 49, 50, 32, 8, 74, 24, 178, 179, 102, 103, 24, 2, 104, 180],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27,
#   67],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27,
#   67,
#   7],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27,
#   67,
#   7,
#   182],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27,
#   67,
#   7,
#   182,
#   70],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27,
#   67,
#   7,
#   182,
#   70,
#   183],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27,
#   67,
#   7,
#   182,
#   70,
#   183,
#   6],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27,
#   67,
#   7,
#   182,
#   70,
#   183,
#   6,
#   1],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27,
#   67,
#   7,
#   182,
#   70,
#   183,
#   6,
#   1,
#   105],
#  [1,
#   73,
#   56,
#   7,
#   49,
#   50,
#   32,
#   8,
#   74,
#   24,
#   178,
#   179,
#   102,
#   103,
#   24,
#   2,
#   104,
#   180,
#   57,
#   75,
#   181,
#   1,
#   73,
#   27,
#   67,
#   7,
#   182,
#   70,
#   183,
#   6,
#   1,
#   105,
#   13],
#  [12, 7],
#  [12, 7, 184],
#  [12, 7, 184, 15],
#  [12, 7, 184, 15, 1],
#  [12, 7, 184, 15, 1, 37],
#  [12, 7, 184, 15, 1, 37, 13],
#  [17, 185],
#  [17, 185, 186],
#  [17, 185, 186, 187],
#  [17, 185, 186, 187, 2],
#  [17, 185, 186, 187, 2, 188],
#  [17, 185, 186, 187, 2, 188, 106],
#  [17, 185, 186, 187, 2, 188, 106, 9],
#  [17, 185, 186, 187, 2, 188, 106, 9, 189],
#  [17, 185, 186, 187, 2, 188, 106, 9, 189, 76],
#  [17, 185, 186, 187, 2, 188, 106, 9, 189, 76, 190],
#  [102, 191],
#  [28, 54],
#  [28, 54, 192],
#  [28, 54, 192, 193],
#  [28, 54, 192, 193, 194],
#  [28, 54, 192, 193, 194, 195],
#  [28, 54, 192, 193, 194, 195, 196],
#  [28, 197],
#  [28, 197, 2],
#  [28, 197, 2, 198],
#  [199, 6],
#  [199, 6, 28],
#  [199, 6, 28, 54],
#  [107, 200],
#  [107, 200, 6],
#  [107, 200, 6, 201],
#  [103, 24],
#  [103, 24, 202],
#  [203, 2],
#  [203, 2, 204],
#  [77, 57],
#  [77, 57, 75],
#  [4, 3],
#  [4, 3, 205],
#  [4, 3, 205, 1],
#  [4, 3, 205, 1, 206],
#  [4, 3, 205, 1, 206, 207],
#  [4, 3, 205, 1, 206, 207, 18],
#  [4, 3, 205, 1, 206, 207, 18, 29],
#  [4, 3, 205, 1, 206, 207, 18, 29, 108],
#  [4, 3, 205, 1, 206, 207, 18, 29, 108, 78],
#  [4, 3, 205, 1, 206, 207, 18, 29, 108, 78, 51],
#  [4, 3, 205, 1, 206, 207, 18, 29, 108, 78, 51, 52],
#  [4, 3, 205, 1, 206, 207, 18, 29, 108, 78, 51, 52, 208],
#  [10, 79],
#  [10, 79, 24],
#  [10, 79, 24, 2],
#  [10, 79, 24, 2, 109],
#  [10, 79, 24, 2, 109, 25],
#  [10, 79, 24, 2, 109, 25, 209],
#  [11, 15],
#  [11, 15, 1],
#  [11, 15, 1, 110],
#  [11, 15, 1, 110, 80],
#  [11, 15, 1, 110, 80, 210],
#  [11, 15, 1, 110, 80, 210, 79],
#  [11, 15, 1, 110, 80, 210, 79, 24],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2, 211],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2, 211, 111],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2, 211, 111, 212],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2, 211, 111, 212, 10],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2, 211, 111, 212, 10, 25],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2, 211, 111, 212, 10, 25, 213],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2, 211, 111, 212, 10, 25, 213, 32],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2, 211, 111, 212, 10, 25, 213, 32, 214],
#  [11, 15, 1, 110, 80, 210, 79, 24, 2, 211, 111, 212, 10, 25, 213, 32, 214, 2],
#  [11,
#   15,
#   1,
#   110,
#   80,
#   210,
#   79,
#   24,
#   2,
#   211,
#   111,
#   212,
#   10,
#   25,
#   213,
#   32,
#   214,
#   2,
#   215],
#  [11,
#   15,
#   1,
#   110,
#   80,
#   210,
#   79,
#   24,
#   2,
#   211,
#   111,
#   212,
#   10,
#   25,
#   213,
#   32,
#   214,
#   2,
#   215,
#   216],
#  [12, 33],
#  [12, 33, 5],
#  [12, 33, 5, 217],
#  [12, 33, 5, 217, 8],
#  [12, 33, 5, 217, 8, 34],
#  [12, 33, 5, 217, 8, 34, 58],
#  [12, 33, 5, 217, 8, 34, 58, 10],
#  [12, 33, 5, 217, 8, 34, 58, 10, 5],
#  [12, 33, 5, 217, 8, 34, 58, 10, 5, 41],
#  [12, 33, 5, 217, 8, 34, 58, 10, 5, 41, 112],
#  [11, 22],
#  [11, 22, 34],
#  [11, 22, 34, 16],
#  [11, 22, 34, 16, 26],
#  [11, 22, 34, 16, 26, 113],
#  [11, 22, 34, 16, 26, 113, 2],
#  [11, 22, 34, 16, 26, 113, 2, 218],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1, 24],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1, 24, 219],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1, 24, 219, 220],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1, 24, 219, 220, 30],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1, 24, 219, 220, 30, 4],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1, 24, 219, 220, 30, 4, 3],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1, 24, 219, 220, 30, 4, 3, 19],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1, 24, 219, 220, 30, 4, 3, 19, 114],
#  [11, 22, 34, 16, 26, 113, 2, 218, 9, 1, 24, 219, 220, 30, 4, 3, 19, 114, 81],
#  [11,
#   22,
#   34,
#   16,
#   26,
#   113,
#   2,
#   218,
#   9,
#   1,
#   24,
#   219,
#   220,
#   30,
#   4,
#   3,
#   19,
#   114,
#   81,
#   115],
#  [11,
#   22,
#   34,
#   16,
#   26,
#   113,
#   2,
#   218,
#   9,
#   1,
#   24,
#   219,
#   220,
#   30,
#   4,
#   3,
#   19,
#   114,
#   81,
#   115,
#   20],
#  [11,
#   22,
#   34,
#   16,
#   26,
#   113,
#   2,
#   218,
#   9,
#   1,
#   24,
#   219,
#   220,
#   30,
#   4,
#   3,
#   19,
#   114,
#   81,
#   115,
#   20,
#   221],
#  [11,
#   22,
#   34,
#   16,
#   26,
#   113,
#   2,
#   218,
#   9,
#   1,
#   24,
#   219,
#   220,
#   30,
#   4,
#   3,
#   19,
#   114,
#   81,
#   115,
#   20,
#   221,
#   45],
#  [38, 3],
#  [38, 3, 5],
#  [38, 3, 5, 222],
#  [38, 3, 5, 222, 1],
#  [38, 3, 5, 222, 1, 82],
#  [38, 3, 5, 222, 1, 82, 116],
#  [4, 3],
#  [4, 3, 117],
#  [4, 3, 117, 1],
#  [4, 3, 117, 1, 44],
#  [4, 3, 117, 1, 44, 116],
#  [4, 3, 117, 1, 44, 116, 15],
#  [4, 3, 117, 1, 44, 116, 15, 1],
#  [4, 3, 117, 1, 44, 116, 15, 1, 223],
#  [4, 3, 117, 1, 44, 116, 15, 1, 223, 83],
#  [4, 3, 117, 1, 44, 116, 15, 1, 223, 83, 224],
#  [4, 3, 117, 1, 44, 116, 15, 1, 223, 83, 224, 225],
#  [78, 226],
#  [78, 226, 83],
#  [78, 226, 83, 227],
#  [78, 226, 83, 227, 228],
#  [78, 226, 83, 227, 228, 229],
#  [78, 226, 83, 227, 228, 229, 230],
#  [12, 7],
#  [12, 7, 1],
#  [12, 7, 1, 231],
#  [12, 7, 1, 231, 232],
#  [12, 7, 1, 231, 232, 56],
#  [12, 7, 1, 231, 232, 56, 14],
#  [12, 7, 1, 231, 232, 56, 14, 84],
#  [12, 7, 1, 231, 232, 56, 14, 84, 34],
#  [12, 7, 1, 231, 232, 56, 14, 84, 34, 82],
#  [84, 34],
#  [84, 34, 82],
#  [84, 34, 82, 233],
#  [84, 34, 82, 233, 6],
#  [84, 34, 82, 233, 6, 234],
#  [84, 34, 82, 233, 6, 234, 235],
#  [84, 34, 82, 233, 6, 234, 235, 236],
#  [84, 34, 82, 233, 6, 234, 235, 236, 237],
#  [84, 34, 82, 233, 6, 234, 235, 236, 237, 8],
#  [84, 34, 82, 233, 6, 234, 235, 236, 237, 8, 2],
#  [84, 34, 82, 233, 6, 234, 235, 236, 237, 8, 2, 238],
#  [84, 34, 82, 233, 6, 234, 235, 236, 237, 8, 2, 238, 18],
#  [84, 34, 82, 233, 6, 234, 235, 236, 237, 8, 2, 238, 18, 239],
#  [84, 34, 82, 233, 6, 234, 235, 236, 237, 8, 2, 238, 18, 239, 16],
#  [240, 111],
#  [240, 111, 10],
#  [240, 111, 10, 25],
#  [240, 111, 10, 25, 241],
#  [240, 111, 10, 25, 241, 242],
#  [240, 111, 10, 25, 241, 242, 16],
#  [1, 16],
#  [1, 16, 10],
#  [1, 16, 10, 25],
#  [1, 16, 10, 25, 118],
#  [1, 16, 10, 25, 118, 15],
#  [1, 16, 10, 25, 118, 15, 243],
#  [1, 16, 10, 25, 118, 15, 243, 2],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244, 245],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244, 245, 246],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244, 245, 246, 114],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244, 245, 246, 114, 247],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244, 245, 246, 114, 247, 9],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244, 245, 246, 114, 247, 9, 248],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244, 245, 246, 114, 247, 9, 248, 6],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244, 245, 246, 114, 247, 9, 248, 6, 22],
#  [1, 16, 10, 25, 118, 15, 243, 2, 244, 245, 246, 114, 247, 9, 248, 6, 22, 69],
#  [85, 10],
#  [85, 10, 47],
#  [85, 10, 47, 25],
#  [85, 10, 47, 25, 249],
#  [85, 10, 47, 25, 249, 100],
#  [85, 10, 47, 25, 249, 100, 250],
#  [85, 10, 47, 25, 249, 100, 250, 16],
#  [119, 69],
#  [119, 69, 59],
#  [119, 69, 59, 72],
#  [119, 69, 59, 72, 60],
#  [119, 69, 59, 72, 60, 2],
#  [119, 69, 59, 72, 60, 2, 251],
#  [119, 69, 59, 72, 60, 2, 251, 252],
#  [119, 69, 59, 72, 60, 2, 251, 252, 253],
#  [119, 69, 59, 72, 60, 2, 251, 252, 253, 61],
#  [119, 69, 59, 72, 60, 2, 251, 252, 253, 61, 58],
#  [119, 69, 59, 72, 60, 2, 251, 252, 253, 61, 58, 32],
#  [119, 69, 59, 72, 60, 2, 251, 252, 253, 61, 58, 32, 1],
#  [119, 69, 59, 72, 60, 2, 251, 252, 253, 61, 58, 32, 1, 254],
#  [119, 69, 59, 72, 60, 2, 251, 252, 253, 61, 58, 32, 1, 254, 86],
#  [119, 69, 59, 72, 60, 2, 251, 252, 253, 61, 58, 32, 1, 254, 86, 2],
#  [119, 69, 59, 72, 60, 2, 251, 252, 253, 61, 58, 32, 1, 254, 86, 2, 255],
#  [3, 47],
#  [3, 47, 48],
#  [3, 47, 48, 120],
#  [3, 47, 48, 120, 87],
#  [3, 47, 48, 120, 87, 256],
#  [3, 47, 48, 120, 87, 256, 23],
#  [257, 1],
#  [257, 1, 13],
#  [257, 1, 13, 258],
#  [257, 1, 13, 258, 48],
#  [257, 1, 13, 258, 48, 259],
#  [257, 1, 13, 258, 48, 259, 2],
#  [257, 1, 13, 258, 48, 259, 2, 260],
#  [257, 1, 13, 258, 48, 259, 2, 260, 88],
#  [257, 1, 13, 258, 48, 259, 2, 260, 88, 261],
#  [257, 1, 13, 258, 48, 259, 2, 260, 88, 261, 262],
#  [257, 1, 13, 258, 48, 259, 2, 260, 88, 261, 262, 121],
#  [3, 5],
#  [3, 5, 23],
#  [3, 5, 23, 1],
#  [3, 5, 23, 1, 13],
#  [3, 5, 23, 1, 13, 15],
#  [3, 5, 23, 1, 13, 15, 1],
#  [3, 5, 23, 1, 13, 15, 1, 263],
#  [11, 47],
#  [11, 47, 3],
#  [11, 47, 3, 23],
#  [11, 47, 3, 23, 81],
#  [11, 47, 3, 23, 81, 1],
#  [11, 47, 3, 23, 81, 1, 30],
#  [11, 47, 3, 23, 81, 1, 30, 19],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264, 4],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264, 4, 112],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264, 4, 112, 14],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264, 4, 112, 14, 22],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264, 4, 112, 14, 22, 122],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264, 4, 112, 14, 22, 122, 16],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264, 4, 112, 14, 22, 122, 16, 265],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264, 4, 112, 14, 22, 122, 16, 265, 31],
#  [11, 47, 3, 23, 81, 1, 30, 19, 264, 4, 112, 14, 22, 122, 16, 265, 31, 21],
#  [10, 5],
#  [10, 5, 41],
#  [10, 5, 41, 19],
#  [10, 5, 41, 19, 9],
#  [10, 5, 41, 19, 9, 266],
#  [10, 5, 41, 19, 9, 266, 123],
#  [10, 5, 41, 19, 9, 266, 123, 33],
#  [10, 5, 41, 19, 9, 266, 123, 33, 5],
#  [10, 5, 41, 19, 9, 266, 123, 33, 5, 23],
#  [10, 5, 41, 19, 9, 266, 123, 33, 5, 23, 124],
#  [11, 4],
#  [11, 4, 10],
#  [11, 4, 10, 41],
#  [11, 4, 10, 41, 125],
#  [11, 4, 10, 41, 125, 19],
#  [11, 4, 10, 41, 125, 19, 9],
#  [11, 4, 10, 41, 125, 19, 9, 22],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267, 113],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267, 113, 106],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267, 113, 106, 2],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267, 113, 106, 2, 126],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267, 113, 106, 2, 126, 89],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267, 113, 106, 2, 126, 89, 4],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267, 113, 106, 2, 126, 89, 4, 268],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267, 113, 106, 2, 126, 89, 4, 268, 20],
#  [11, 4, 10, 41, 125, 19, 9, 22, 267, 113, 106, 2, 126, 89, 4, 268, 20, 45],
#  [42, 17],
#  [42, 17, 269],
#  [42, 17, 269, 9],
#  [42, 17, 269, 9, 127],
#  [42, 17, 269, 9, 127, 270],
#  [42, 17, 269, 9, 127, 270, 2],
#  [42, 17, 269, 9, 127, 270, 2, 62],
#  [11, 271],
#  [11, 271, 126],
#  [11, 271, 126, 2],
#  [11, 271, 126, 2, 8],
#  [11, 271, 126, 2, 8, 272],
#  [11, 271, 126, 2, 8, 272, 128],
#  [11, 271, 126, 2, 8, 272, 128, 90],
#  [11, 271, 126, 2, 8, 272, 128, 90, 26],
#  [11, 271, 126, 2, 8, 272, 128, 90, 26, 129],
#  [11, 271, 126, 2, 8, 272, 128, 90, 26, 129, 14],
#  [11, 271, 126, 2, 8, 272, 128, 90, 26, 129, 14, 1],
#  [11, 271, 126, 2, 8, 272, 128, 90, 26, 129, 14, 1, 273],
#  [11, 271, 126, 2, 8, 272, 128, 90, 26, 129, 14, 1, 273, 274],
#  [11, 271, 126, 2, 8, 272, 128, 90, 26, 129, 14, 1, 273, 274, 275],
#  [11, 271, 126, 2, 8, 272, 128, 90, 26, 129, 14, 1, 273, 274, 275, 26],
#  [11, 271, 126, 2, 8, 272, 128, 90, 26, 129, 14, 1, 273, 274, 275, 26, 276],
#  [11,
#   271,
#   126,
#   2,
#   8,
#   272,
#   128,
#   90,
#   26,
#   129,
#   14,
#   1,
#   273,
#   274,
#   275,
#   26,
#   276,
#   53],
#  [11,
#   271,
#   126,
#   2,
#   8,
#   272,
#   128,
#   90,
#   26,
#   129,
#   14,
#   1,
#   273,
#   274,
#   275,
#   26,
#   276,
#   53,
#   1],
#  [11,
#   271,
#   126,
#   2,
#   8,
#   272,
#   128,
#   90,
#   26,
#   129,
#   14,
#   1,
#   273,
#   274,
#   275,
#   26,
#   276,
#   53,
#   1,
#   30],
#  [11,
#   271,
#   126,
#   2,
#   8,
#   272,
#   128,
#   90,
#   26,
#   129,
#   14,
#   1,
#   273,
#   274,
#   275,
#   26,
#   276,
#   53,
#   1,
#   30,
#   63],
#  [10, 17],
#  [10, 17, 277],
#  [10, 17, 277, 18],
#  [10, 17, 277, 18, 104],
#  [10, 17, 277, 18, 104, 57],
#  [10, 17, 277, 18, 104, 57, 75],
#  [11, 61],
#  [11, 61, 80],
#  [11, 61, 80, 278],
#  [11, 61, 80, 278, 8],
#  [11, 61, 80, 278, 8, 57],
#  [11, 61, 80, 278, 8, 57, 279],
#  [11, 61, 80, 278, 8, 57, 279, 280],
#  [11, 61, 80, 278, 8, 57, 279, 280, 130],
#  [11, 61, 80, 278, 8, 57, 279, 280, 130, 131],
#  [11, 61, 80, 278, 8, 57, 279, 280, 130, 131, 132],
#  [11, 61, 80, 278, 8, 57, 279, 280, 130, 131, 132, 39],
#  [11, 61, 80, 278, 8, 57, 279, 280, 130, 131, 132, 39, 281],
#  [11, 61, 80, 278, 8, 57, 279, 280, 130, 131, 132, 39, 281, 282],
#  [11, 61, 80, 278, 8, 57, 279, 280, 130, 131, 132, 39, 281, 282, 28],
#  [11, 61, 80, 278, 8, 57, 279, 280, 130, 131, 132, 39, 281, 282, 28, 283],
#  [11, 61, 80, 278, 8, 57, 279, 280, 130, 131, 132, 39, 281, 282, 28, 283, 28],
#  [11,
#   61,
#   80,
#   278,
#   8,
#   57,
#   279,
#   280,
#   130,
#   131,
#   132,
#   39,
#   281,
#   282,
#   28,
#   283,
#   28,
#   35],
#  [11,
#   61,
#   80,
#   278,
#   8,
#   57,
#   279,
#   280,
#   130,
#   131,
#   132,
#   39,
#   281,
#   282,
#   28,
#   283,
#   28,
#   35,
#   133],
#  [11,
#   61,
#   80,
#   278,
#   8,
#   57,
#   279,
#   280,
#   130,
#   131,
#   132,
#   39,
#   281,
#   282,
#   28,
#   283,
#   28,
#   35,
#   133,
#   134],
#  [11,
#   61,
#   80,
#   278,
#   8,
#   57,
#   279,
#   280,
#   130,
#   131,
#   132,
#   39,
#   281,
#   282,
#   28,
#   283,
#   28,
#   35,
#   133,
#   134,
#   284],
#  [11,
#   61,
#   80,
#   278,
#   8,
#   57,
#   279,
#   280,
#   130,
#   131,
#   132,
#   39,
#   281,
#   282,
#   28,
#   283,
#   28,
#   35,
#   133,
#   134,
#   284,
#   15],
#  [11,
#   61,
#   80,
#   278,
#   8,
#   57,
#   279,
#   280,
#   130,
#   131,
#   132,
#   39,
#   281,
#   282,
#   28,
#   283,
#   28,
#   35,
#   133,
#   134,
#   284,
#   15,
#   39],
#  [38, 3],
#  [38, 3, 17],
#  [38, 3, 17, 285],
#  [38, 3, 17, 285, 6],
#  [38, 3, 17, 285, 6, 87],
#  [38, 3, 17, 285, 6, 87, 35],
#  [38, 3, 17, 285, 6, 87, 35, 27],
#  [38, 3, 17, 285, 6, 87, 35, 27, 286],
#  [38, 3, 17, 285, 6, 87, 35, 27, 286, 36],
#  [4, 3],
#  [4, 3, 91],
#  [4, 3, 91, 92],
#  [4, 3, 91, 92, 40],
#  [4, 3, 91, 92, 40, 36],
#  [4, 3, 91, 92, 40, 36, 51],
#  [4, 3, 91, 92, 40, 36, 51, 52],
#  [35, 53],
#  [35, 53, 1],
#  [35, 53, 1, 287],
#  [35, 53, 1, 287, 288],
#  [35, 53, 1, 287, 288, 18],
#  [35, 53, 1, 287, 288, 18, 20],
#  [35, 53, 1, 287, 288, 18, 20, 30],
#  [35, 53, 1, 287, 288, 18, 20, 30, 63],
#  [21, 135],
#  [38, 42],
#  [38, 42, 17],
#  [38, 42, 17, 136],
#  [38, 42, 17, 136, 55],
#  [55, 3],
#  [55, 3, 25],
#  [55, 3, 25, 93],
#  [55, 3, 25, 93, 53],
#  [55, 3, 25, 93, 53, 29],
#  [55, 3, 25, 93, 53, 29, 137],
#  [55, 3, 25, 93, 53, 29, 137, 108],
#  [78, 51],
#  [78, 51, 52],
#  [17, 289],
#  [17, 289, 290],
#  [17, 289, 290, 291],
#  [17, 289, 290, 291, 2],
#  [17, 289, 290, 291, 2, 292],
#  [17, 289, 290, 291, 2, 292, 293],
#  [17, 289, 290, 291, 2, 292, 293, 294],
#  [17, 289, 290, 291, 2, 292, 293, 294, 55],
#  [3, 5],
#  [3, 5, 46],
#  [3, 5, 46, 1],
#  [3, 5, 46, 1, 125],
#  [3, 5, 46, 1, 125, 295],
#  [3, 5, 46, 1, 125, 295, 40],
#  [3, 5, 46, 1, 125, 295, 40, 89],
#  [11, 4],
#  [11, 4, 3],
#  [11, 4, 3, 296],
#  [11, 4, 3, 296, 9],
#  [11, 4, 3, 296, 9, 46],
#  [11, 4, 3, 296, 9, 46, 22],
#  [11, 4, 3, 296, 9, 46, 22, 138],
#  [11, 4, 3, 296, 9, 46, 22, 138, 50],
#  [11, 4, 3, 296, 9, 46, 22, 138, 50, 297],
#  [11, 4, 3, 296, 9, 46, 22, 138, 50, 297, 9],
#  [11, 4, 3, 296, 9, 46, 22, 138, 50, 297, 9, 59],
#  [11, 4, 3, 296, 9, 46, 22, 138, 50, 297, 9, 59, 8],
#  [11, 4, 3, 296, 9, 46, 22, 138, 50, 297, 9, 59, 8, 298],
#  [11, 4, 3, 296, 9, 46, 22, 138, 50, 297, 9, 59, 8, 298, 299],
#  [12, 7],
#  [12, 7, 1],
#  [12, 7, 1, 44],
#  [12, 7, 1, 44, 300],
#  [12, 7, 1, 44, 300, 139],
#  [84, 45],
#  [84, 45, 7],
#  [84, 45, 7, 301],
#  [84, 45, 7, 301, 6],
#  [84, 45, 7, 301, 6, 302],
#  [84, 45, 7, 301, 6, 302, 140],
#  [84, 45, 7, 301, 6, 302, 140, 48],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1, 303],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1, 303, 14],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1, 303, 14, 21],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1, 303, 14, 21, 33],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1, 303, 14, 21, 33, 4],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1, 303, 14, 21, 33, 4, 23],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1, 303, 14, 21, 33, 4, 23, 18],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1, 303, 14, 21, 33, 4, 23, 18, 141],
#  [84, 45, 7, 301, 6, 302, 140, 48, 1, 303, 14, 21, 33, 4, 23, 18, 141, 304],
#  [84,
#   45,
#   7,
#   301,
#   6,
#   302,
#   140,
#   48,
#   1,
#   303,
#   14,
#   21,
#   33,
#   4,
#   23,
#   18,
#   141,
#   304,
#   20],
#  [84,
#   45,
#   7,
#   301,
#   6,
#   302,
#   140,
#   48,
#   1,
#   303,
#   14,
#   21,
#   33,
#   4,
#   23,
#   18,
#   141,
#   304,
#   20,
#   142],
#  [84,
#   45,
#   7,
#   301,
#   6,
#   302,
#   140,
#   48,
#   1,
#   303,
#   14,
#   21,
#   33,
#   4,
#   23,
#   18,
#   141,
#   304,
#   20,
#   142,
#   21],
#  [84,
#   45,
#   7,
#   301,
#   6,
#   302,
#   140,
#   48,
#   1,
#   303,
#   14,
#   21,
#   33,
#   4,
#   23,
#   18,
#   141,
#   304,
#   20,
#   142,
#   21,
#   7],
#  [84,
#   45,
#   7,
#   301,
#   6,
#   302,
#   140,
#   48,
#   1,
#   303,
#   14,
#   21,
#   33,
#   4,
#   23,
#   18,
#   141,
#   304,
#   20,
#   142,
#   21,
#   7,
#   305],
#  [84,
#   45,
#   7,
#   301,
#   6,
#   302,
#   140,
#   48,
#   1,
#   303,
#   14,
#   21,
#   33,
#   4,
#   23,
#   18,
#   141,
#   304,
#   20,
#   142,
#   21,
#   7,
#   305,
#   306],
#  [84,
#   45,
#   7,
#   301,
#   6,
#   302,
#   140,
#   48,
#   1,
#   303,
#   14,
#   21,
#   33,
#   4,
#   23,
#   18,
#   141,
#   304,
#   20,
#   142,
#   21,
#   7,
#   305,
#   306,
#   141],
#  [84,
#   45,
#   7,
#   301,
#   6,
#   302,
#   140,
#   48,
#   1,
#   303,
#   14,
#   21,
#   33,
#   4,
#   23,
#   18,
#   141,
#   304,
#   20,
#   142,
#   21,
#   7,
#   305,
#   306,
#   141,
#   307],
#  [12, 33],
#  [12, 33, 5],
#  [12, 33, 5, 308],
#  [12, 33, 5, 308, 94],
#  [12, 33, 5, 308, 94, 309],
#  [12, 33, 5, 308, 94, 309, 32],
#  [12, 33, 5, 308, 94, 309, 32, 1],
#  [12, 33, 5, 308, 94, 309, 32, 1, 27],
#  [12, 33, 5, 308, 94, 309, 32, 1, 27, 31],
#  [12, 33, 5, 308, 94, 309, 32, 1, 27, 31, 21],
#  [17, 310],
#  [17, 310, 8],
#  [17, 310, 8, 49],
#  [17, 310, 8, 49, 311],
#  [17, 310, 8, 49, 311, 143],
#  [17, 310, 8, 49, 311, 143, 312],
#  [17, 310, 8, 49, 311, 143, 312, 4],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3, 60],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3, 60, 92],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3, 60, 92, 115],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3, 60, 92, 115, 138],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3, 60, 92, 115, 138, 140],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3, 60, 92, 115, 138, 140, 14],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3, 60, 92, 115, 138, 140, 14, 21],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3, 60, 92, 115, 138, 140, 14, 21, 9],
#  [17, 310, 8, 49, 311, 143, 312, 4, 3, 60, 92, 115, 138, 140, 14, 21, 9, 313],
#  [17,
#   310,
#   8,
#   49,
#   311,
#   143,
#   312,
#   4,
#   3,
#   60,
#   92,
#   115,
#   138,
#   140,
#   14,
#   21,
#   9,
#   313,
#   8],
#  [17,
#   310,
#   8,
#   49,
#   311,
#   143,
#   312,
#   4,
#   3,
#   60,
#   92,
#   115,
#   138,
#   140,
#   14,
#   21,
#   9,
#   313,
#   8,
#   143],
#  [17,
#   310,
#   8,
#   49,
#   311,
#   143,
#   312,
#   4,
#   3,
#   60,
#   92,
#   115,
#   138,
#   140,
#   14,
#   21,
#   9,
#   313,
#   8,
#   143,
#   88],
#  [17,
#   310,
#   8,
#   49,
#   311,
#   143,
#   312,
#   4,
#   3,
#   60,
#   92,
#   115,
#   138,
#   140,
#   14,
#   21,
#   9,
#   313,
#   8,
#   143,
#   88,
#   95],
#  [17,
#   310,
#   8,
#   49,
#   311,
#   143,
#   312,
#   4,
#   3,
#   60,
#   92,
#   115,
#   138,
#   140,
#   14,
#   21,
#   9,
#   313,
#   8,
#   143,
#   88,
#   95,
#   314],
#  [5, 34],
#  [5, 34, 315],
#  [5, 34, 315, 39],
#  [5, 34, 315, 39, 2],
#  [5, 34, 315, 39, 2, 316],
#  [5, 34, 315, 39, 2, 316, 46],
#  [5, 34, 315, 39, 2, 316, 46, 64],
#  [5, 34, 315, 39, 2, 316, 46, 64, 144],
#  [5, 34, 315, 39, 2, 316, 46, 64, 144, 317],
#  [5, 34, 315, 39, 2, 316, 46, 64, 144, 317, 12],
#  [5, 34, 315, 39, 2, 316, 46, 64, 144, 317, 12, 318],
#  [5, 34, 315, 39, 2, 316, 46, 64, 144, 317, 12, 318, 5],
#  [5, 34, 315, 39, 2, 316, 46, 64, 144, 317, 12, 318, 5, 42],
#  [4, 3],
#  [4, 3, 91],
#  [4, 3, 91, 29],
#  [4, 3, 91, 29, 319],
#  [4, 3, 91, 29, 319, 40],
#  [4, 3, 91, 29, 319, 40, 36],
#  [4, 3, 91, 29, 319, 40, 36, 51],
#  [4, 3, 91, 29, 319, 40, 36, 51, 52],
#  [9, 59],
#  [9, 59, 72],
#  [9, 59, 72, 320],
#  [9, 59, 72, 320, 21],
#  [9, 59, 72, 320, 21, 86],
#  [9, 59, 72, 320, 21, 86, 64],
#  [9, 59, 72, 320, 21, 86, 64, 321],
#  [9, 59, 72, 320, 21, 86, 64, 321, 35],
#  [9, 59, 72, 320, 21, 86, 64, 321, 35, 322],
#  [10, 5],
#  [10, 5, 145],
#  [10, 5, 145, 41],
#  [10, 5, 145, 41, 323],
#  [10, 5, 145, 41, 323, 33],
#  [10, 5, 145, 41, 323, 33, 5],
#  [10, 5, 145, 41, 323, 33, 5, 324],
#  [10, 5, 145, 41, 323, 33, 5, 324, 93],
#  [10, 5, 145, 41, 323, 33, 5, 324, 93, 1],
#  [10, 5, 145, 41, 323, 33, 5, 324, 93, 1, 325],
#  [10, 5, 145, 41, 323, 33, 5, 324, 93, 1, 325, 21],
#  [146, 147],
#  [146, 147, 326],
#  [146, 147, 326, 327],
#  [146, 147, 326, 327, 148],
#  [146, 147, 326, 327, 148, 20],
#  [146, 147, 326, 327, 148, 20, 30],
#  [146, 147, 326, 327, 148, 20, 30, 19],
#  [146, 147, 326, 327, 148, 20, 30, 19, 10],
#  [146, 147, 326, 327, 148, 20, 30, 19, 10, 25],
#  [146, 147, 326, 327, 148, 20, 30, 19, 10, 25, 328],
#  [146, 147, 326, 327, 148, 20, 30, 19, 10, 25, 328, 149],
#  [146, 147, 326, 327, 148, 20, 30, 19, 10, 25, 328, 149, 1],
#  [146, 147, 326, 327, 148, 20, 30, 19, 10, 25, 328, 149, 1, 142],
#  [146, 147, 326, 327, 148, 20, 30, 19, 10, 25, 328, 149, 1, 142, 21],
#  [146, 147, 326, 327, 148, 20, 30, 19, 10, 25, 328, 149, 1, 142, 21, 7],
#  [146, 147, 326, 327, 148, 20, 30, 19, 10, 25, 328, 149, 1, 142, 21, 7, 93],
#  [31, 135],
#  [85, 329],
#  [85, 329, 3],
#  [85, 329, 3, 5],
#  [85, 329, 3, 5, 330],
#  [85, 329, 3, 5, 330, 150],
#  [85, 329, 3, 5, 330, 150, 151],
#  [85, 329, 3, 5, 330, 150, 151, 31],
#  [85, 329, 3, 5, 330, 150, 151, 31, 331],
#  [4, 3],
#  [4, 3, 117],
#  [4, 3, 117, 22],
#  [4, 3, 117, 22, 151],
#  [4, 3, 117, 22, 151, 6],
#  [4, 3, 117, 22, 151, 6, 1],
#  [4, 3, 117, 22, 151, 6, 1, 56],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20, 45],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20, 45, 139],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20, 45, 139, 89],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20, 45, 139, 89, 1],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20, 45, 139, 89, 1, 105],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20, 45, 139, 89, 1, 105, 27],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20, 45, 139, 89, 1, 105, 27, 67],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20, 45, 139, 89, 1, 105, 27, 67, 7],
#  [4, 3, 117, 22, 151, 6, 1, 56, 14, 20, 45, 139, 89, 1, 105, 27, 67, 7, 150],
#  [4,
#   3,
#   117,
#   22,
#   151,
#   6,
#   1,
#   56,
#   14,
#   20,
#   45,
#   139,
#   89,
#   1,
#   105,
#   27,
#   67,
#   7,
#   150,
#   146],
#  [4,
#   3,
#   117,
#   22,
#   151,
#   6,
#   1,
#   56,
#   14,
#   20,
#   45,
#   139,
#   89,
#   1,
#   105,
#   27,
#   67,
#   7,
#   150,
#   146,
#   332],
#  [4,
#   3,
#   117,
#   22,
#   151,
#   6,
#   1,
#   56,
#   14,
#   20,
#   45,
#   139,
#   89,
#   1,
#   105,
#   27,
#   67,
#   7,
#   150,
#   146,
#   332,
#   19],
#  [4,
#   3,
#   117,
#   22,
#   151,
#   6,
#   1,
#   56,
#   14,
#   20,
#   45,
#   139,
#   89,
#   1,
#   105,
#   27,
#   67,
#   7,
#   150,
#   146,
#   332,
#   19,
#   9],
#  [4,
#   3,
#   117,
#   22,
#   151,
#   6,
#   1,
#   56,
#   14,
#   20,
#   45,
#   139,
#   89,
#   1,
#   105,
#   27,
#   67,
#   7,
#   150,
#   146,
#   332,
#   19,
#   9,
#   1],
#  [4,
#   3,
#   117,
#   22,
#   151,
#   6,
#   1,
#   56,
#   14,
#   20,
#   45,
#   139,
#   89,
#   1,
#   105,
#   27,
#   67,
#   7,
#   150,
#   146,
#   332,
#   19,
#   9,
#   1,
#   123],
#  [4,
#   3,
#   117,
#   22,
#   151,
#   6,
#   1,
#   56,
#   14,
#   20,
#   45,
#   139,
#   89,
#   1,
#   105,
#   27,
#   67,
#   7,
#   150,
#   146,
#   332,
#   19,
#   9,
#   1,
#   123,
#   149],
#  [4,
#   3,
#   117,
#   22,
#   151,
#   6,
#   1,
#   56,
#   14,
#   20,
#   45,
#   139,
#   89,
#   1,
#   105,
#   27,
#   67,
#   7,
#   150,
#   146,
#   332,
#   19,
#   9,
#   1,
#   123,
#   149,
#   333],
#  [4,
#   3,
#   117,
#   22,
#   151,
#   6,
#   1,
#   56,
#   14,
#   20,
#   45,
#   139,
#   89,
#   1,
#   105,
#   27,
#   67,
#   7,
#   150,
#   146,
#   332,
#   19,
#   9,
#   1,
#   123,
#   149,
#   333,
#   334],
#  [335, 336],
#  [335, 336, 4],
#  [335, 336, 4, 152],
#  [335, 336, 4, 152, 153],
#  [335, 336, 4, 152, 153, 19],
#  [17, 337],
#  [17, 337, 338],
#  [17, 337, 338, 339],
#  [17, 337, 338, 339, 2],
#  [17, 337, 338, 339, 2, 340],
#  [17, 337, 338, 339, 2, 340, 29],
#  [17, 337, 338, 339, 2, 340, 29, 341],
#  [17, 337, 338, 339, 2, 340, 29, 341, 61],
#  [17, 337, 338, 339, 2, 340, 29, 341, 61, 154],
#  [17, 337, 338, 339, 2, 340, 29, 341, 61, 154, 153],
#  [17, 337, 338, 339, 2, 340, 29, 341, 61, 154, 153, 19],
#  [17, 337, 338, 339, 2, 340, 29, 341, 61, 154, 153, 19, 7],
#  [17, 337, 338, 339, 2, 340, 29, 341, 61, 154, 153, 19, 7, 94],
#  [17, 337, 338, 339, 2, 340, 29, 341, 61, 154, 153, 19, 7, 94, 342],
#  [17, 337, 338, 339, 2, 340, 29, 341, 61, 154, 153, 19, 7, 94, 342, 40],
#  [17, 337, 338, 339, 2, 340, 29, 341, 61, 154, 153, 19, 7, 94, 342, 40, 71],
#  [17,
#   337,
#   338,
#   339,
#   2,
#   340,
#   29,
#   341,
#   61,
#   154,
#   153,
#   19,
#   7,
#   94,
#   342,
#   40,
#   71,
#   343],
#  [85, 42],
#  [85, 42, 5],
#  [85, 42, 5, 96],
#  [85, 42, 5, 96, 95],
#  [85, 42, 5, 96, 95, 31],
#  [85, 42, 5, 96, 95, 31, 1],
#  [85, 42, 5, 96, 95, 31, 1, 58],
#  [8, 83],
#  [8, 83, 155],
#  [8, 83, 155, 7],
#  [8, 83, 155, 7, 65],
#  [8, 83, 155, 7, 65, 15],
#  [8, 83, 155, 7, 65, 15, 20],
#  [8, 83, 155, 7, 65, 15, 20, 30],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63, 6],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63, 6, 344],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63, 6, 344, 156],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63, 6, 344, 156, 29],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63, 6, 344, 156, 29, 157],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63, 6, 344, 156, 29, 157, 345],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63, 6, 344, 156, 29, 157, 345, 64],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63, 6, 344, 156, 29, 157, 345, 64, 43],
#  [8, 83, 155, 7, 65, 15, 20, 30, 63, 6, 344, 156, 29, 157, 345, 64, 43, 18],
#  [8,
#   83,
#   155,
#   7,
#   65,
#   15,
#   20,
#   30,
#   63,
#   6,
#   344,
#   156,
#   29,
#   157,
#   345,
#   64,
#   43,
#   18,
#   43],
#  [8,
#   83,
#   155,
#   7,
#   65,
#   15,
#   20,
#   30,
#   63,
#   6,
#   344,
#   156,
#   29,
#   157,
#   345,
#   64,
#   43,
#   18,
#   43,
#   158],
#  [8,
#   83,
#   155,
#   7,
#   65,
#   15,
#   20,
#   30,
#   63,
#   6,
#   344,
#   156,
#   29,
#   157,
#   345,
#   64,
#   43,
#   18,
#   43,
#   158,
#   16],
#  [8,
#   83,
#   155,
#   7,
#   65,
#   15,
#   20,
#   30,
#   63,
#   6,
#   344,
#   156,
#   29,
#   157,
#   345,
#   64,
#   43,
#   18,
#   43,
#   158,
#   16,
#   61],
#  [8,
#   83,
#   155,
#   7,
#   65,
#   15,
#   20,
#   30,
#   63,
#   6,
#   344,
#   156,
#   29,
#   157,
#   345,
#   64,
#   43,
#   18,
#   43,
#   158,
#   16,
#   61,
#   346],
#  [33, 5],
#  [33, 5, 23],
#  [33, 5, 23, 124],
#  [33, 5, 23, 124, 3],
#  [33, 5, 23, 124, 3, 5],
#  [33, 5, 23, 124, 3, 5, 145],
#  [33, 5, 23, 124, 3, 5, 145, 96],
#  [33, 5, 23, 124, 3, 5, 145, 96, 122],
#  [33, 5, 23, 124, 3, 5, 145, 96, 122, 58],
#  [33, 5, 23, 124, 3, 5, 145, 96, 122, 58, 156],
#  [11, 347],
#  [11, 347, 348],
#  [11, 347, 348, 1],
#  [11, 347, 348, 1, 80],
#  [11, 347, 348, 1, 80, 2],
#  [11, 347, 348, 1, 80, 2, 349],
#  [11, 347, 348, 1, 80, 2, 349, 350],
#  [11, 347, 348, 1, 80, 2, 349, 350, 15],
#  [11, 347, 348, 1, 80, 2, 349, 350, 15, 1],
#  [11, 347, 348, 1, 80, 2, 349, 350, 15, 1, 351],
#  [11, 347, 348, 1, 80, 2, 349, 350, 15, 1, 351, 155],
#  [12, 33],
#  [12, 33, 5],
#  [12, 33, 5, 352],
#  [12, 33, 5, 352, 19],
#  [12, 33, 5, 352, 19, 9],
#  [12, 33, 5, 352, 19, 9, 1],
#  [12, 33, 5, 352, 19, 9, 1, 30],
#  [4, 3],
#  [4, 3, 353],
#  [4, 3, 353, 20],
#  [4, 3, 353, 20, 354],
#  [4, 3, 353, 20, 354, 81],
#  [4, 3, 353, 20, 354, 81, 355],
#  [4, 3, 353, 20, 354, 81, 355, 20],
#  [4, 3, 353, 20, 354, 81, 355, 20, 119],
#  [4, 3, 353, 20, 354, 81, 355, 20, 119, 60],
#  [4, 3, 353, 20, 354, 81, 355, 20, 119, 60, 87],
#  [4, 3, 353, 20, 354, 81, 355, 20, 119, 60, 87, 36],
#  [4, 3, 353, 20, 354, 81, 355, 20, 119, 60, 87, 36, 7],
#  [4, 3, 353, 20, 354, 81, 355, 20, 119, 60, 87, 36, 7, 65],
#  [4, 3, 353, 20, 354, 81, 355, 20, 119, 60, 87, 36, 7, 65, 356],
#  [4, 3, 353, 20, 354, 81, 355, 20, 119, 60, 87, 36, 7, 65, 356, 49],
#  [97, 98],
#  [97, 98, 36],
#  [12, 7],
#  [12, 7, 1],
#  [12, 7, 1, 97],
#  [12, 7, 1, 97, 357],
#  [12, 7, 1, 97, 357, 358],
#  [359, 26],
#  [359, 26, 360],
#  [359, 26, 360, 361],
#  [359, 26, 360, 361, 362],
#  [4, 159],
#  [4, 159, 74],
#  [4, 159, 74, 22],
#  [4, 159, 74, 22, 49],
#  [4, 159, 74, 22, 49, 50],
#  [4, 159, 74, 22, 49, 50, 14],
#  [4, 159, 74, 22, 49, 50, 14, 21],
#  [4, 159],
#  [4, 159, 363],
#  [4, 159, 363, 2],
#  [4, 159, 363, 2, 127],
#  [4, 159, 363, 2, 127, 22],
#  [4, 159, 363, 2, 127, 22, 27],
#  [4, 159, 363, 2, 127, 22, 27, 62],
#  [3, 5],
#  [3, 5, 46],
#  [3, 5, 46, 6],
#  [3, 5, 46, 6, 364],
#  [3, 5, 46, 6, 364, 50],
#  [3, 5, 46, 6, 364, 50, 365],
#  [11, 8],
#  [11, 8, 366],
#  [11, 8, 366, 367],
#  [11, 8, 366, 367, 368],
#  [11, 8, 366, 367, 368, 369],
#  [11, 8, 366, 367, 368, 369, 86],
#  [11, 8, 366, 367, 368, 369, 86, 10],
#  [11, 8, 366, 367, 368, 369, 86, 10, 25],
#  [11, 8, 366, 367, 368, 369, 86, 10, 25, 65],
#  [11, 8, 366, 367, 368, 369, 86, 10, 25, 65, 18],
#  [11, 8, 366, 367, 368, 369, 86, 10, 25, 65, 18, 20],
#  [11, 8, 366, 367, 368, 369, 86, 10, 25, 65, 18, 20, 63],
#  [11, 8, 366, 367, 368, 369, 86, 10, 25, 65, 18, 20, 63, 6],
#  [11, 8, 366, 367, 368, 369, 86, 10, 25, 65, 18, 20, 63, 6, 370],
#  [11, 8, 366, 367, 368, 369, 86, 10, 25, 65, 18, 20, 63, 6, 370, 50],
#  [42, 4],
#  [42, 4, 152],
#  [42, 4, 152, 66],
#  [42, 4, 152, 66, 160],
#  [11, 148],
#  [11, 148, 66],
#  [11, 148, 66, 160],
#  [11, 148, 66, 160, 371],
#  [11, 148, 66, 160, 371, 66],
#  [11, 148, 66, 160, 371, 66, 372],
#  [11, 148, 66, 160, 371, 66, 372, 17],
#  [11, 148, 66, 160, 371, 66, 372, 17, 373],
#  [11, 148, 66, 160, 371, 66, 372, 17, 373, 4],
#  [11, 148, 66, 160, 371, 66, 372, 17, 373, 4, 32],
#  [77, 99],
#  [77, 99, 374],
#  [375, 376],
#  [375, 376, 377],
#  [375, 376, 377, 16],
#  [378, 379],
#  [378, 379, 32],
#  [378, 379, 32, 76],
#  [378, 379, 32, 76, 157],
#  [161, 2],
#  [161, 2, 380],
#  [161, 2, 380, 381],
#  [10, 5],
#  [10, 5, 41],
#  [10, 5, 41, 162],
#  [10, 5, 41, 162, 382],
#  [10, 5, 41, 162, 382, 66],
#  [88, 1],
#  [88, 1, 13],
#  [88, 1, 13, 383],
#  [88, 1, 13, 383, 384],
#  [88, 1, 13, 383, 384, 99],
#  [88, 1, 13, 383, 384, 99, 2],
#  [88, 1, 13, 383, 384, 99, 2, 98],
#  [88, 1, 13, 383, 384, 99, 2, 98, 36],
#  [88, 1, 13, 383, 384, 99, 2, 98, 36, 94],
#  [88, 1, 13, 383, 384, 99, 2, 98, 36, 94, 162],
#  [88, 1, 13, 383, 384, 99, 2, 98, 36, 94, 162, 385],
#  [12, 386],
#  [12, 386, 14],
#  [12, 386, 14, 62],
#  [12, 386, 14, 62, 26],
#  [12, 386, 14, 62, 26, 129],
#  [12, 386, 14, 62, 26, 129, 14],
#  [12, 386, 14, 62, 26, 129, 14, 1],
#  [12, 386, 14, 62, 26, 129, 14, 1, 77],
#  [47, 74],
#  [47, 74, 387],
#  [47, 74, 387, 388],
#  [47, 74, 387, 388, 62],
#  [47, 74, 387, 388, 62, 2],
#  [47, 74, 387, 388, 62, 2, 43],
#  [47, 74, 387, 388, 62, 2, 43, 128],
#  [47, 74, 387, 388, 62, 2, 43, 128, 90],
#  [47, 74, 387, 388, 62, 2, 43, 128, 90, 130],
#  [47, 74, 387, 388, 62, 2, 43, 128, 90, 130, 131],
#  [389, 390],
#  [389, 390, 391],
#  [389, 390, 391, 15],
#  [389, 390, 391, 15, 39],
#  [132, 392],
#  [132, 392, 393],
#  [132, 392, 393, 107],
#  [99, 8],
#  [99, 8, 394],
#  [99, 8, 394, 6],
#  [99, 8, 394, 6, 395],
#  [99, 8, 394, 6, 395, 396],
#  [133, 134],
#  [133, 134, 397],
#  [133, 134, 397, 398],
#  [133, 134, 397, 398, 399],
#  [12, 7],
#  [12, 7, 1],
#  [12, 7, 1, 400],
#  [12, 7, 1, 400, 14],
#  [12, 7, 1, 400, 14, 1],
#  [12, 7, 1, 400, 14, 1, 97],
#  [401, 26],
#  [401, 26, 402],
#  [401, 26, 402, 403],
#  [401, 26, 402, 403, 2],
#  [401, 26, 402, 403, 2, 404],
#  [401, 26, 402, 403, 2, 404, 64],
#  [401, 26, 402, 403, 2, 404, 64, 405],
#  [401, 26, 402, 403, 2, 404, 64, 405, 406],
#  [401, 26, 402, 403, 2, 404, 64, 405, 406, 8],
#  [401, 26, 402, 403, 2, 404, 64, 405, 406, 8, 407],
#  [401, 26, 402, 403, 2, 404, 64, 405, 406, 8, 407, 408],
#  [401, 26, 402, 403, 2, 404, 64, 405, 406, 8, 407, 408, 3],
#  [401, 26, 402, 403, 2, 404, 64, 405, 406, 8, 407, 408, 3, 25],
#  [401, 26, 402, 403, 2, 404, 64, 405, 406, 8, 407, 408, 3, 25, 409],
#  [401, 26, 402, 403, 2, 404, 64, 405, 406, 8, 407, 408, 3, 25, 409, 6],
#  [401, 26, 402, 403, 2, 404, 64, 405, 406, 8, 407, 408, 3, 25, 409, 6, 70],
#  [401,
#   26,
#   402,
#   403,
#   2,
#   404,
#   64,
#   405,
#   406,
#   8,
#   407,
#   408,
#   3,
#   25,
#   409,
#   6,
#   70,
#   410],
#  [401,
#   26,
#   402,
#   403,
#   2,
#   404,
#   64,
#   405,
#   406,
#   8,
#   407,
#   408,
#   3,
#   25,
#   409,
#   6,
#   70,
#   410,
#   411],
#  [3, 5],
#  [3, 5, 147],
#  [3, 5, 147, 24],
#  [3, 5, 147, 24, 31],
#  [3, 5, 147, 24, 31, 412],
#  [3, 5, 147, 24, 31, 412, 1],
#  [3, 5, 147, 24, 31, 412, 1, 13],
#  [11, 4],
#  [11, 4, 3],
#  [11, 4, 3, 23],
#  [11, 4, 3, 23, 29],
#  [11, 4, 3, 23, 29, 110],
#  [11, 4, 3, 23, 29, 110, 68],
#  [11, 4, 3, 23, 29, 110, 68, 413],
#  [11, 4, 3, 23, 29, 110, 68, 413, 414],
#  [11, 4, 3, 23, 29, 110, 68, 413, 414, 6],
#  [11, 4, 3, 23, 29, 110, 68, 413, 414, 6, 79],
#  [11, 4, 3, 23, 29, 110, 68, 413, 414, 6, 79, 24],
#  [11, 4, 3, 23, 29, 110, 68, 413, 414, 6, 79, 24, 109],
#  [11, 4, 3, 23, 29, 110, 68, 413, 414, 6, 79, 24, 109, 2],
#  [11, 4, 3, 23, 29, 110, 68, 413, 414, 6, 79, 24, 109, 2, 415],
#  [11, 4, 3, 23, 29, 110, 68, 413, 414, 6, 79, 24, 109, 2, 415, 416],
#  [91, 417],
#  [38, 3],
#  [38, 3, 5],
#  [38, 3, 5, 96],
#  [38, 3, 5, 96, 418],
#  [38, 3, 5, 96, 418, 95],
#  [4, 3],
#  [4, 3, 60],
#  [4, 3, 60, 92],
#  [4, 3, 60, 92, 40],
#  [4, 3, 60, 92, 40, 419],
#  [4, 3, 60, 92, 40, 419, 51],
#  [4, 3, 60, 92, 40, 419, 51, 52],
#  [35, 23],
#  [35, 23, 29],
#  [35, 23, 29, 137],
#  [35, 23, 29, 137, 420],
#  [35, 23, 29, 137, 420, 421],
#  [35, 23, 29, 137, 420, 421, 6],
#  [35, 23, 29, 137, 420, 421, 6, 422],
#  [10, 5],
#  [10, 5, 41],
#  [10, 5, 41, 37],
#  [10, 5, 41, 37, 36],
#  [10, 5, 41, 37, 36, 31],
#  [10, 5, 41, 37, 36, 31, 27],
#  [10, 5, 41, 37, 36, 31, 27, 423],
#  [11, 424],
#  [11, 424, 59],
#  [11, 424, 59, 19],
#  [11, 424, 59, 19, 9],
#  [11, 424, 59, 19, 9, 44],
#  [11, 424, 59, 19, 9, 44, 425],
#  [11, 424, 59, 19, 9, 44, 425, 426],
#  [11, 424, 59, 19, 9, 44, 425, 426, 2],
#  [11, 424, 59, 19, 9, 44, 425, 426, 2, 98],
#  [11, 424, 59, 19, 9, 44, 425, 426, 2, 98, 427],
#  [11, 424, 59, 19, 9, 44, 425, 426, 2, 98, 427, 6],
#  [11, 424, 59, 19, 9, 44, 425, 426, 2, 98, 427, 6, 43],
#  [11, 424, 59, 19, 9, 44, 425, 426, 2, 98, 427, 6, 43, 154],
#  [11, 424, 59, 19, 9, 44, 425, 426, 2, 98, 427, 6, 43, 154, 31],
#  [11, 424, 59, 19, 9, 44, 425, 426, 2, 98, 427, 6, 43, 154, 31, 428],
#  [42, 4],
#  [42, 4, 429],
#  [42, 4, 429, 163],
#  [42, 4, 429, 163, 35],
#  [42, 4, 429, 163, 35, 430],
#  [11, 17],
#  [11, 17, 431],
#  [11, 17, 431, 432],
#  [11, 17, 431, 432, 44],
#  [11, 17, 431, 432, 44, 163],
#  [11, 17, 431, 432, 44, 163, 32],
#  [11, 17, 431, 432, 44, 163, 32, 433],
#  [11, 17, 431, 432, 44, 163, 32, 433, 434],
#  [11, 17, 431, 432, 44, 163, 32, 433, 434, 2],
#  [11, 17, 431, 432, 44, 163, 32, 433, 434, 2, 161],
#  [11, 17, 431, 432, 44, 163, 32, 433, 434, 2, 161, 435],
#  [11, 17, 431, 432, 44, 163, 32, 433, 434, 2, 161, 435, 6],
#  [11, 17, 431, 432, 44, 163, 32, 433, 434, 2, 161, 435, 6, 436],
#  [11, 17, 431, 432, 44, 163, 32, 433, 434, 2, 161, 435, 6, 436, 437],
#  [38, 26],
#  [38, 26, 1],
#  [38, 26, 1, 16],
#  [38, 26, 1, 16, 118],
#  [16, 26],
#  [16, 26, 438],
#  [16, 26, 438, 34],
#  [16, 26, 438, 34, 18],
#  [16, 26, 438, 34, 18, 158],
#  [16, 26, 438, 34, 18, 158, 2],
#  [16, 26, 438, 34, 18, 158, 2, 439],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53, 29],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53, 29, 30],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53, 29, 30, 440],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53, 29, 30, 440, 18],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53, 29, 30, 440, 18, 441],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53, 29, 30, 440, 18, 441, 442],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53, 29, 30, 440, 18, 441, 442, 26],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53, 29, 30, 440, 18, 441, 442, 26, 65],
#  [16, 26, 438, 34, 18, 158, 2, 439, 53, 29, 30, 440, 18, 441, 442, 26, 65, 15],
#  [16,
#   26,
#   438,
#   34,
#   18,
#   158,
#   2,
#   439,
#   53,
#   29,
#   30,
#   440,
#   18,
#   441,
#   442,
#   26,
#   65,
#   15,
#   443],
#  [16,
#   26,
#   438,
#   34,
#   18,
#   158,
#   2,
#   439,
#   53,
#   29,
#   30,
#   440,
#   18,
#   441,
#   442,
#   26,
#   65,
#   15,
#   443,
#   444],
#  [16,
#   26,
#   438,
#   34,
#   18,
#   158,
#   2,
#   439,
#   53,
#   29,
#   30,
#   440,
#   18,
#   441,
#   442,
#   26,
#   65,
#   15,
#   443,
#   444,
#   2],
#  [16,
#   26,
#   438,
#   34,
#   18,
#   158,
#   2,
#   439,
#   53,
#   29,
#   30,
#   440,
#   18,
#   441,
#   442,
#   26,
#   65,
#   15,
#   443,
#   444,
#   2,
#   445],
#  [15, 446],
#  [1, 28],
#  [1, 28, 54],
#  [1, 28, 54, 68],
#  [1, 28, 54, 68, 37],
#  [1, 28, 54, 68, 37, 13],
#  [1, 28, 54, 68, 37, 13, 39],
#  [1, 28, 54, 68, 37, 13, 39, 7],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8, 49],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8, 49, 101],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8, 49, 101, 447],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8, 49, 101, 447, 448],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8, 49, 101, 447, 448, 449],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8, 49, 101, 447, 448, 449, 450],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8, 49, 101, 447, 448, 449, 450, 37],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8, 49, 101, 447, 448, 449, 450, 37, 2],
#  [1, 28, 54, 68, 37, 13, 39, 7, 8, 49, 101, 447, 448, 449, 450, 37, 2, 90],
#  [1,
#   28,
#   54,
#   68,
#   37,
#   13,
#   39,
#   7,
#   8,
#   49,
#   101,
#   447,
#   448,
#   449,
#   450,
#   37,
#   2,
#   90,
#   451],
#  [1,
#   28,
#   54,
#   68,
#   37,
#   13,
#   39,
#   7,
#   8,
#   49,
#   101,
#   447,
#   448,
#   449,
#   450,
#   37,
#   2,
#   90,
#   451,
#   24],
#  [1,
#   28,
#   54,
#   68,
#   37,
#   13,
#   39,
#   7,
#   8,
#   49,
#   101,
#   447,
#   448,
#   449,
#   450,
#   37,
#   2,
#   90,
#   451,
#   24,
#   6],
#  [1,
#   28,
#   54,
#   68,
#   37,
#   13,
#   39,
#   7,
#   8,
#   49,
#   101,
#   447,
#   448,
#   449,
#   450,
#   37,
#   2,
#   90,
#   451,
#   24,
#   6,
#   452],
#  [1,
#   28,
#   54,
#   68,
#   37,
#   13,
#   39,
#   7,
#   8,
#   49,
#   101,
#   447,
#   448,
#   449,
#   450,
#   37,
#   2,
#   90,
#   451,
#   24,
#   6,
#   452,
#   28],
#  [1,
#   28,
#   54,
#   68,
#   37,
#   13,
#   39,
#   7,
#   8,
#   49,
#   101,
#   447,
#   448,
#   449,
#   450,
#   37,
#   2,
#   90,
#   451,
#   24,
#   6,
#   452,
#   28,
#   453],
#  ...]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0, 100,   1],
#        [  0,   0,   0, ..., 100,   1,  13],
#        [  0,   0,   0, ...,   0,  12,   7],
#        ...,
#        [  0,   0,   1, ...,   2,  43,  18],
#        [  0,   1,  28, ...,  43,  18,  43],
#        [  1,  28,  54, ...,  18,  43,  37]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (1028, 51)

# %%
y.shape
# Out:
# (1028,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=459)

# %%
y.shape
# Out:
# (1028, 459)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
#model = Sequential()
#model.add(Embedding(459, 100, input_length=56))
#model.add(LSTM(150))
#model.add(LSTM(150))
#model.add(Dense(459, activation='softmax'))

#from keras.models import Sequential
#from keras.layers import Embedding, LSTM, Dense

model = Sequential()
model.add(Embedding(459, 100))             # ← removed input_length
model.add(LSTM(150, return_sequences=True))
model.add(LSTM(150))
model.add(Dense(459, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.0284 - loss: 6.0572
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.0359 - loss: 5.6817
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.0404 - loss: 5.6275
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - accuracy: 0.0418 - loss: 5.5951
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - accuracy: 0.0417 - loss: 5.5636
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.0384 - loss: 5.5380
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.0405 - loss: 5.5320
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 194ms/step - accuracy: 0.0574 - loss: 5.4149
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.0444 - loss: 5.2428
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - accuracy: 0.0556 - loss: 5.0793
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 161ms/step - accuracy: 0.0523 - loss: 4.9549
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - accuracy: 0.0675 - loss: 4.8176
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 185ms/step - accuracy: 0.0786 - loss: 4.6149
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.0950 - loss: 4.4964
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.0970 - loss: 4.3955
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.1026 - loss: 4.2261
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.1310 - loss: 4.1332
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.1544 - loss: 3.9345
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.1433 - loss: 3.8815
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - accuracy: 0.1720 - loss: 3.7337
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.1867 - loss: 3.5620
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.2024 - loss: 3.5192
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 183ms/step - accuracy: 0.2390 - loss: 3.4011
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.2752 - loss: 3.2775
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.2843 - loss: 3.2254
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 193ms/step - accuracy: 0.3138 - loss: 3.0939
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.3452 - loss: 2.9728
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - accuracy: 0.3875 - loss: 2.8317
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.4183 - loss: 2.7536
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - accuracy: 0.4441 - loss: 2.6309
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.4725 - loss: 2.5536
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.4889 - loss: 2.4862
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.5367 - loss: 2.3572
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - accuracy: 0.5441 - loss: 2.3606
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.5435 - loss: 2.2788
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.5952 - loss: 2.1260
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.6189 - loss: 2.0336
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.6034 - loss: 1.9925
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - accuracy: 0.6253 - loss: 1.9288
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.6602 - loss: 1.8373
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.6547 - loss: 1.7670
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - accuracy: 0.7124 - loss: 1.6713
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.7044 - loss: 1.6364
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.7254 - loss: 1.5287
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.7516 - loss: 1.4738
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.7621 - loss: 1.4005
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.7512 - loss: 1.3680
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.7802 - loss: 1.3321
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.7912 - loss: 1.2666
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.8157 - loss: 1.2201
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.8093 - loss: 1.1695
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8311 - loss: 1.1072
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.8205 - loss: 1.1148
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.7988 - loss: 1.1102
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.8409 - loss: 1.0023
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.8335 - loss: 0.9933
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - accuracy: 0.8313 - loss: 0.9714
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.8510 - loss: 0.8940
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 0.8558 - loss: 0.8978
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.8669 - loss: 0.8471
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.8740 - loss: 0.8464
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8830 - loss: 0.7775
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 187ms/step - accuracy: 0.8824 - loss: 0.7570
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.8775 - loss: 0.7701
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.8766 - loss: 0.7352
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.8787 - loss: 0.7197
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - accuracy: 0.8809 - loss: 0.6764
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.8894 - loss: 0.6685
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.8910 - loss: 0.6673
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - accuracy: 0.9005 - loss: 0.6280
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 200ms/step - accuracy: 0.9081 - loss: 0.5596
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.8936 - loss: 0.5712
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - accuracy: 0.9011 - loss: 0.5668
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.9008 - loss: 0.5610
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.8870 - loss: 0.5623
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.8946 - loss: 0.5418
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - accuracy: 0.8974 - loss: 0.5225
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9083 - loss: 0.5076
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 174ms/step - accuracy: 0.9105 - loss: 0.4762
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.9139 - loss: 0.4722
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - accuracy: 0.9082 - loss: 0.4696
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.9196 - loss: 0.4393
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.9264 - loss: 0.4059
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.9216 - loss: 0.4282
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.9179 - loss: 0.4293
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.9238 - loss: 0.4024
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - accuracy: 0.9188 - loss: 0.3969
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - accuracy: 0.9089 - loss: 0.4135
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.9190 - loss: 0.3859
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.9296 - loss: 0.3422
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9240 - loss: 0.3536
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 0.9215 - loss: 0.3593
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step - accuracy: 0.9204 - loss: 0.3436
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - accuracy: 0.9286 - loss: 0.3514
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 187ms/step - accuracy: 0.9368 - loss: 0.3175
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.9218 - loss: 0.3363
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.9269 - loss: 0.3210
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.9452 - loss: 0.2956
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - accuracy: 0.9237 - loss: 0.3174
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 208ms/step - accuracy: 0.9258 - loss: 0.3110

# %%
import time
import numpy as np
text = "The Data Science & AI Mentorship"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# The Data Science & AI Mentorship program
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# The Data Science & AI Mentorship program pakistan
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# The Data Science & AI Mentorship program pakistan is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# The Data Science & AI Mentorship program pakistan is a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# The Data Science & AI Mentorship program pakistan is a 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# The Data Science & AI Mentorship program pakistan is a 7 month
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# The Data Science & AI Mentorship program pakistan is a 7 month guided
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# The Data Science & AI Mentorship program pakistan is a 7 month guided journey
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# The Data Science & AI Mentorship program pakistan is a 7 month guided journey blending
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# The Data Science & AI Mentorship program pakistan is a 7 month guided journey blending affordability

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'can': 3,
#  'you': 4,
#  'i': 5,
#  'for': 6,
#  'is': 7,
#  'a': 8,
#  'to': 9,
#  'will': 10,
#  'yes': 11,
#  'what': 12,
#  'program': 13,
#  'of': 14,
#  'in': 15,
#  'sessions': 16,
#  'we': 17,
#  'on': 18,
#  'access': 19,
#  'your': 20,
#  'payment': 21,
#  'all': 22,
#  'join': 23,
#  'learning': 24,
#  'be': 25,
#  'are': 26,
#  'course': 27,
#  'data': 28,
#  'our': 29,
#  'lms': 30,
#  'after': 31,
#  'with': 32,
#  'if': 33,
#  'live': 34,
#  'or': 35,
#  'support': 36,
#  'mentorship': 37,
#  'where': 38,
#  'pakistan': 39,
#  'at': 40,
#  'get': 41,
#  'do': 42,
#  'one': 43,
#  'monthly': 44,
#  'subscription': 45,
#  'pay': 46,
#  'students': 47,
#  'from': 48,
#  '7': 49,
#  'months': 50,
#  'datasciencepakistan': 51,
#  'org': 52,
#  'through': 53,
#  'science': 54,
#  'payments': 55,
#  'duration': 56,
#  'case': 57,
#  'session': 58,
#  'receive': 59,
#  'email': 60,
#  'every': 61,
#  'projects': 62,
#  'dashboard': 63,
#  'via': 64,
#  'available': 65,
#  'placement': 66,
#  'fee': 67,
#  'ai': 68,
#  'learners': 69,
#  'rs': 70,
#  'this': 71,
#  'an': 72,
#  'total': 73,
#  'complete': 74,
#  'studies': 75,
#  'industry': 76,
#  'portfolio': 77,
#  'https': 78,
#  'deep': 79,
#  'module': 80,
#  'anytime': 81,
#  'class': 82,
#  'google': 83,
#  'each': 84,
#  'how': 85,
#  'link': 86,
#  'technical': 87,
#  'no': 88,
#  'once': 89,
#  'project': 90,
#  'contact': 91,
#  'us': 92,
#  'made': 93,
#  'not': 94,
#  'questions': 95,
#  'ask': 96,
#  'certificate': 97,
#  'career': 98,
#  'building': 99,
#  'about': 100,
#  'month': 101,
#  'python': 102,
#  'machine': 103,
#  'real': 104,
#  'entire': 105,
#  'modules': 106,
#  'statistics': 107,
#  'website': 108,
#  'nlp': 109,
#  'advanced': 110,
#  'language': 111,
#  'recordings': 112,
#  'recorded': 113,
#  'them': 114,
#  'within': 115,
#  'schedule': 116,
#  'view': 117,
#  'conducted': 118,
#  'registered': 119,
#  'non': 120,
#  'background': 121,
#  'previous': 122,
#  'content': 123,
#  'late': 124,
#  'full': 125,
#  'assignments': 126,
#  'submit': 127,
#  'capstone': 128,
#  'part': 129,
#  'such': 130,
#  'as': 131,
#  'analyzing': 132,
#  'covid': 133,
#  '19': 134,
#  'registration': 135,
#  'make': 136,
#  'official': 137,
#  'seven': 138,
#  'period': 139,
#  'days': 140,
#  '10th': 141,
#  'next': 142,
#  'refund': 143,
#  'local': 144,
#  'still': 145,
#  'you’ll': 146,
#  'continue': 147,
#  'but': 148,
#  'until': 149,
#  'paid': 150,
#  'videos': 151,
#  'provide': 152,
#  'lifetime': 153,
#  'year': 154,
#  'form': 155,
#  'doubts': 156,
#  'mentors': 157,
#  'zoom': 158,
#  'must': 159,
#  'assistance': 160,
#  'internship': 161,
#  'guaranteed': 162,
#  'hackathons': 163,
#  'tech': 164,
#  'dsaim': 165,
#  '2025': 166,
#  'follows': 167,
#  'model': 168,
#  '850': 169,
#  'per': 170,
#  'allows': 171,
#  'over': 172,
#  'affordable': 173,
#  'cost': 174,
#  'without': 175,
#  'large': 176,
#  'upfront': 177,
#  'roadmap': 178,
#  'covering': 179,
#  'world': 180,
#  'hence': 181,
#  'around': 182,
#  '5950': 183,
#  'included': 184,
#  'cover': 185,
#  'both': 186,
#  'theoretical': 187,
#  'practical': 188,
#  'ensure': 189,
#  'readiness': 190,
#  'fundamentals': 191,
#  'libraries': 192,
#  'numpy': 193,
#  'pandas': 194,
#  'matplotlib': 195,
#  'seaborn': 196,
#  'cleaning': 197,
#  'analysis': 198,
#  'sql': 199,
#  'mathematics': 200,
#  'ml': 201,
#  'algorithms': 202,
#  'mlops': 203,
#  'deployment': 204,
#  'check': 205,
#  'detailed': 206,
#  'outline': 207,
#  'programs': 208,
#  'covered': 209,
#  'optional': 210,
#  'natural': 211,
#  'processing': 212,
#  'introduced': 213,
#  'tensorflow': 214,
#  'hugging': 215,
#  'face': 216,
#  'miss': 217,
#  'uploaded': 218,
#  'management': 219,
#  'system': 220,
#  'active': 221,
#  'find': 222,
#  'shared': 223,
#  'sheet': 224,
#  'here': 225,
#  'docs': 226,
#  'com': 227,
#  'spreadsheets': 228,
#  'd': 229,
#  'pkdsaim2025': 230,
#  'average': 231,
#  'time': 232,
#  'runs': 233,
#  '2': 234,
#  'hours': 235,
#  'including': 236,
#  'q': 237,
#  'hands': 238,
#  'practice': 239,
#  'which': 240,
#  'used': 241,
#  'during': 242,
#  'urdu': 243,
#  'english': 244,
#  'mixed': 245,
#  'making': 246,
#  'easy': 247,
#  'follow': 248,
#  'informed': 249,
#  'upcoming': 250,
#  'whatsapp': 251,
#  'message': 252,
#  'before': 253,
#  'joining': 254,
#  'resources': 255,
#  'backgrounds': 256,
#  'absolutely': 257,
#  'starts': 258,
#  'scratch': 259,
#  'assumes': 260,
#  'prior': 261,
#  'programming': 262,
#  'middle': 263,
#  'gives': 264,
#  'instantly': 265,
#  'old': 266,
#  'previously': 267,
#  'activate': 268,
#  'have': 269,
#  'tasks': 270,
#  'weekly': 271,
#  'final': 272,
#  'evaluation': 273,
#  'process': 274,
#  'submissions': 275,
#  'done': 276,
#  'work': 277,
#  'includes': 278,
#  'study': 279,
#  '—': 280,
#  'stock': 281,
#  'exchange': 282,
#  'weather': 283,
#  'trends': 284,
#  'reach': 285,
#  'related': 286,
#  '“help”': 287,
#  'section': 288,
#  'accept': 289,
#  'jazzcash': 290,
#  'easypaisa': 291,
#  'debit': 292,
#  'credit': 293,
#  'card': 294,
#  'amount': 295,
#  'choose': 296,
#  'together': 297,
#  '10': 298,
#  'discount': 299,
#  'validity': 300,
#  'valid': 301,
#  '30': 302,
#  'date': 303,
#  'january': 304,
#  'due': 305,
#  'by': 306,
#  'february': 307,
#  'am': 308,
#  'satisfied': 309,
#  'offer': 310,
#  'day': 311,
#  'policy': 312,
#  'request': 313,
#  'asked': 314,
#  'outside': 315,
#  'cannot': 316,
#  'gateways': 317,
#  'should': 318,
#  'team': 319,
#  'international': 320,
#  'paypal': 321,
#  'stripe': 322,
#  'updates': 323,
#  'haven’t': 324,
#  'latest': 325,
#  'receiving': 326,
#  'newsletters': 327,
#  'paused': 328,
#  'long': 329,
#  'watch': 330,
#  'purchase': 331,
#  'retain': 332,
#  'august': 333,
#  '2026': 334,
#  'why': 335,
#  'don’t': 336,
#  'keep': 337,
#  'costs': 338,
#  'low': 339,
#  'update': 340,
#  'curriculum': 341,
#  'feasible': 342,
#  'price': 343,
#  'submitting': 344,
#  'respond': 345,
#  'friday': 346,
#  'just': 347,
#  'select': 348,
#  'week': 349,
#  'number': 350,
#  'doubt': 351,
#  'lose': 352,
#  'recover': 353,
#  'account': 354,
#  'using': 355,
#  '24': 356,
#  'eligibility': 357,
#  'criteria': 358,
#  'there': 359,
#  'two': 360,
#  'main': 361,
#  'requirements': 362,
#  'attempt': 363,
#  'missed': 364,
#  'later': 365,
#  'special': 366,
#  '“make': 367,
#  'up': 368,
#  'fee”': 369,
#  'pending': 370,
#  '≠': 371,
#  'guarantee': 372,
#  'help': 373,
#  'workshops': 374,
#  'resume': 375,
#  'linkedin': 376,
#  'profile': 377,
#  'mock': 378,
#  'interviews': 379,
#  'freelancing': 380,
#  'guidance': 381,
#  'job': 382,
#  'provides': 383,
#  'skill': 384,
#  'jobs': 385,
#  'type': 386,
#  '3': 387,
#  'mini': 388,
#  'predicting': 389,
#  'electricity': 390,
#  'demand': 391,
#  'psl': 392,
#  'player': 393,
#  'chatbot': 394,
#  'customer': 395,
#  'queries': 396,
#  'vaccination': 397,
#  'trend': 398,
#  'visualization': 399,
#  'format': 400,
#  'certificates': 401,
#  'digital': 402,
#  'pdf': 403,
#  'verifiable': 404,
#  'qr': 405,
#  'code': 406,
#  'printed': 407,
#  'version': 408,
#  'mailed': 409,
#  '400': 410,
#  'extra': 411,
#  'completing': 412,
#  'fellowship': 413,
#  'aaf': 414,
#  'computer': 415,
#  'vision': 416,
#  'communication': 417,
#  'general': 418,
#  'info': 419,
#  'telegram': 420,
#  'community': 421,
#  'discussions': 422,
#  'completion': 423,
#  'alumni': 424,
#  'mentor': 425,
#  'meetups': 426,
#  'clinics': 427,
#  'graduation': 428,
#  'organize': 429,
#  'challenges': 430,
#  'conduct': 431,
#  'bi': 432,
#  'cash': 433,
#  'prizes': 434,
#  'opportunities': 435,
#  'top': 436,
#  'performers': 437,
#  'hosted': 438,
#  'managed': 439,
#  'platform': 440,
#  'site': 441,
#  'classes': 442,
#  'karachi': 443,
#  'lahore': 444,
#  'islamabad': 445,
#  'short': 446,
#  'guided': 447,
#  'journey': 448,
#  'blending': 449,
#  'affordability': 450,
#  'based': 451,
#  'aspiring': 452,
#  'scientists': 453,
#  'whether': 454,
#  'you’re': 455,
#  'structured': 456,
#  'ready': 457,
#  'datasets': 458}
